# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
path = './drive/MyDrive/Colab Notebooks/'

# %% [markdown]
# # [2019년 인구수](https://jumin.mois.go.kr/ageStatMonth.do)

# %%
# https://jumin.mois.go.kr/ageStatMonth.do
df = pd.read_csv(path + "2019년_인구수.csv", encoding='cp949')

# %%
df
# Out:
#                      행정구역 2019년07월_계_총인구수 2019년07월_계_연령구간인구수 2019년07월_계_0~9세  \
# 0        전국  (0000000000)      51,845,612         51,845,612       4,224,547
# 1     서울특별시  (1100000000)       9,751,415          9,751,415         673,846
# 2     부산광역시  (2600000000)       3,425,317          3,425,317         246,721
# 3     대구광역시  (2700000000)       2,448,666          2,448,666         190,935
# 4     인천광역시  (2800000000)       2,956,828          2,956,828         246,289
# 5     광주광역시  (2900000000)       1,459,486          1,459,486         128,392
# 6     대전광역시  (3000000000)       1,481,701          1,481,701         124,743
# 7     울산광역시  (3100000000)       1,150,891          1,150,891         106,150
# 8   세종특별자치시  (3600000000)         330,298            330,298          46,225
# 9       경기도  (4100000000)      13,176,011         13,176,011       1,195,759
# 10      강원도  (4200000000)       1,540,714          1,540,714         110,790
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 40 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   행정구역                18 non-null     object
#  1   2019년07월_계_총인구수     18 non-null     object
#  2   2019년07월_계_연령구간인구수  18 non-null     object
#  3   2019년07월_계_0~9세     18 non-null     object
#  4   2019년07월_계_10~19세   18 non-null     object
#  5   2019년07월_계_20~29세   18 non-null     object
#  6   2019년07월_계_30~39세   18 non-null     object
#  7   2019년07월_계_40~49세   18 non-null     object
#  8   2019년07월_계_50~59세   18 non-null     object
#  9   2019년07월_계_60~69세   18 non-null     object
#  10  2019년07월_계_70~79세   18 non-null     object
#  11  2019년07월_계_80~89세   18 non-null     object
#  12  2019년07월_계_90~99세   18 non-null     object
#  13  2019년07월_계_100세 이상  18 non-null     object
#  14  2019년07월_남_총인구수     18 non-null     object
# ...

# %% [markdown]
# # Feature 이름 바꾸기

# %%
columns = ['행정구역', '총인구수', '연령구간인구수',
           '0~9세', '10~19세', '20~29세', '30~39세', '40~49세', '50~59세', '60~69세', '70~79세', '80~89세', '90~99세', '100세 이상',
           '남_총인구수', '남_연령구간인구수','0~9세(남)', '10~19세(남)', '20~29세(남)', '30~39세(남)', '40~49세(남)', '50~59세(남)', '60~69세(남)', '70~79세(남)', '80~89세(남)', '90~99세(남)', '100세 이상(남)',
           '여_총인구수', '여_연령구간인구수', '0~9세(여)', '10~19세(여)', '20~29세(여)', '30~39세(여)', '40~49세(여)', '50~59세(여)', '60~69세(여)', '70~79세(여)', '80~89세(여)', '90~99세(여)', '100세 이상(여)']

# %%
len(columns)
# Out:
# 40

# %%
pd.set_option('display.max_columns', None)

# %%
df.columns = columns

# %%
df
# Out:
#                      행정구역        총인구수     연령구간인구수       0~9세     10~19세  \
# 0        전국  (0000000000)  51,845,612  51,845,612  4,224,547  5,029,512
# 1     서울특별시  (1100000000)   9,751,415   9,751,415    673,846    833,628
# 2     부산광역시  (2600000000)   3,425,317   3,425,317    246,721    288,636
# 3     대구광역시  (2700000000)   2,448,666   2,448,666    190,935    242,350
# 4     인천광역시  (2800000000)   2,956,828   2,956,828    246,289    286,626
# 5     광주광역시  (2900000000)   1,459,486   1,459,486    128,392    167,210
# 6     대전광역시  (3000000000)   1,481,701   1,481,701    124,743    155,836
# 7     울산광역시  (3100000000)   1,150,891   1,150,891    106,150    118,294
# 8   세종특별자치시  (3600000000)     330,298     330,298     46,225     38,732
# 9       경기도  (4100000000)  13,176,011  13,176,011  1,195,759  1,371,159
# 10      강원도  (4200000000)   1,540,714   1,540,714    110,790    146,194
# 11     충청북도  (4300000000)   1,599,368   1,599,368    131,186    156,606
# ...

# %% [markdown]
# # 리스트의 특정 값 제거

# %%
columns.remove('연령구간인구수')

# %%
columns.remove('남_연령구간인구수')

# %%
columns.remove('여_연령구간인구수')

# %%
len(columns)
# Out:
# 37

# %%
df = df[columns]
df.head()
# Out:
#                   행정구역        총인구수       0~9세     10~19세     20~29세  \
# 0     전국  (0000000000)  51,845,612  4,224,547  5,029,512  6,820,949
# 1  서울특별시  (1100000000)   9,751,415    673,846    833,628  1,460,274
# 2  부산광역시  (2600000000)   3,425,317    246,721    288,636    440,251
# 3  대구광역시  (2700000000)   2,448,666    190,935    242,350    327,382
# 4  인천광역시  (2800000000)   2,956,828    246,289    286,626    408,897
#
#       30~39세     40~49세     50~59세     60~69세     70~79세     80~89세   90~99세  \
# 0  7,156,062  8,407,480  8,680,063  6,136,869  3,559,132  1,587,612  223,678
# 1  1,526,462  1,570,279  1,548,586  1,167,125    675,484    251,161   38,447
# 2    443,803    520,145    589,027    497,879    279,684    103,830   13,598
# 3    311,620    396,772    431,466    300,047    168,516     70,561    8,365
# 4    426,380    490,791    517,899    328,150    168,735     71,207   10,985
#
#   100세 이상      남_총인구수    0~9세(남)  10~19세(남)  20~29세(남)  30~39세(남)  40~49세(남)  \
# ...

# %% [markdown]
# # 가공한 인구수 저장하기

# %%
df.to_csv(path + "2019년_7월_인구수", index=False)

# %% [markdown]
# # 저장한 인구수 불러오기

# %%
pd.read_csv(path + "2019년_7월_인구수")
# Out:
#                      행정구역        총인구수       0~9세     10~19세     20~29세  \
# 0        전국  (0000000000)  51,845,612  4,224,547  5,029,512  6,820,949
# 1     서울특별시  (1100000000)   9,751,415    673,846    833,628  1,460,274
# 2     부산광역시  (2600000000)   3,425,317    246,721    288,636    440,251
# 3     대구광역시  (2700000000)   2,448,666    190,935    242,350    327,382
# 4     인천광역시  (2800000000)   2,956,828    246,289    286,626    408,897
# 5     광주광역시  (2900000000)   1,459,486    128,392    167,210    207,822
# 6     대전광역시  (3000000000)   1,481,701    124,743    155,836    214,017
# 7     울산광역시  (3100000000)   1,150,891    106,150    118,294    150,789
# 8   세종특별자치시  (3600000000)     330,298     46,225     38,732     35,343
# 9       경기도  (4100000000)  13,176,011  1,195,759  1,371,159  1,763,053
# 10      강원도  (4200000000)   1,540,714    110,790    146,194    180,470
# 11     충청북도  (4300000000)   1,599,368    131,186    156,606    200,478
# ...

# %% [markdown]
# # [2020년 혼인상태](https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1B8000F&vw_cd=MT_ZTITLE&list_id=A2_6&seqNo=&lang_mode=ko&language=kor&obj_var_id=&itm_id=&conn_path=MT_ZTITLE)

# %%
# https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1B8000F&vw_cd=MT_ZTITLE&list_id=A2_6&seqNo=&lang_mode=ko&language=kor&obj_var_id=&itm_id=&conn_path=MT_ZTITLE
df2 = pd.read_csv(path + '2020년_혼인상태.csv', encoding='cp949')

# %%
df2
# Out:
#      행정구역별(시군구)     연령별          2020    2020.1     2020.2   2020.3   2020.4  \
# 0    행정구역별(시군구)     연령별  내국인(15세이상)-계    내국인-미혼  내국인-배우자있음   내국인-사별   내국인-이혼
# 1            전국      합계      43957547  13688458   24575224  3148458  2545407
# 2            전국  15~19세       2422002   2420971        937       28       66
# 3            전국  20~24세       3193316   3148848      39256     1379     3833
# 4            전국  25~29세       3423231   2991167     409775     3426    18863
# ..          ...     ...           ...       ...        ...      ...      ...
# 332     제주특별자치도  65~69세         30856       981      22717     4229     2929
# 333     제주특별자치도  70~74세         24555       358      17562     5277     1358
# 334     제주특별자치도  75~79세         19682       267      12311     6414      690
# 335     제주특별자치도  80~84세         14662       135       7256     7023      248
# 336     제주특별자치도   85세이상         12456       178       3193     8956      129
#
# ...

# %% [markdown]
# # 첫 번째 행을 열로 지정

# %%
df2 = df2.rename(columns=df2.iloc[0])
df2
# Out:
#      행정구역별(시군구)     연령별  내국인(15세이상)-계    내국인-미혼  내국인-배우자있음   내국인-사별   내국인-이혼  \
# 0    행정구역별(시군구)     연령별  내국인(15세이상)-계    내국인-미혼  내국인-배우자있음   내국인-사별   내국인-이혼
# 1            전국      합계      43957547  13688458   24575224  3148458  2545407
# 2            전국  15~19세       2422002   2420971        937       28       66
# 3            전국  20~24세       3193316   3148848      39256     1379     3833
# 4            전국  25~29세       3423231   2991167     409775     3426    18863
# ..          ...     ...           ...       ...        ...      ...      ...
# 332     제주특별자치도  65~69세         30856       981      22717     4229     2929
# 333     제주특별자치도  70~74세         24555       358      17562     5277     1358
# 334     제주특별자치도  75~79세         19682       267      12311     6414      690
# 335     제주특별자치도  80~84세         14662       135       7256     7023      248
# 336     제주특별자치도   85세이상         12456       178       3193     8956      129
#
# ...

# %%
df2.drop(df2.index[0], inplace=True)

# %%
df2
# Out:
#     행정구역별(시군구)     연령별 내국인(15세이상)-계    내국인-미혼 내국인-배우자있음   내국인-사별   내국인-이혼  \
# 1           전국      합계     43957547  13688458  24575224  3148458  2545407
# 2           전국  15~19세      2422002   2420971       937       28       66
# 3           전국  20~24세      3193316   3148848     39256     1379     3833
# 4           전국  25~29세      3423231   2991167    409775     3426    18863
# 5           전국  30~34세      3032832   1710284   1273637     4465    44446
# ..         ...     ...          ...       ...       ...      ...      ...
# 332    제주특별자치도  65~69세        30856       981     22717     4229     2929
# 333    제주특별자치도  70~74세        24555       358     17562     5277     1358
# 334    제주특별자치도  75~79세        19682       267     12311     6414      690
# 335    제주특별자치도  80~84세        14662       135      7256     7023      248
# 336    제주특별자치도   85세이상        12456       178      3193     8956      129
#
#     남자(15세이상)-계    남자-미혼  남자-배우자있음   남자-사별    남자-이혼 여자(15세이상)-계    여자-미혼  \
# ...

# %%
df2.index[0]
# Out:
# 1

# %% [markdown]
# # 가공한 데이터 저장하기

# %%
df2.to_csv(path + '2020년_혼인상태.csv', index=False)

# %% [markdown]
# # 데이터 불러오기

# %%
pd.read_csv(path + '2020년_혼인상태.csv')
# Out:
#     행정구역별(시군구)     연령별  내국인(15세이상)-계    내국인-미혼 내국인-배우자있음   내국인-사별   내국인-이혼  \
# 0           전국      합계      43957547  13688458  24575224  3148458  2545407
# 1           전국  15~19세       2422002   2420971       937       28       66
# 2           전국  20~24세       3193316   3148848     39256     1379     3833
# 3           전국  25~29세       3423231   2991167    409775     3426    18863
# 4           전국  30~34세       3032832   1710284   1273637     4465    44446
# ..         ...     ...           ...       ...       ...      ...      ...
# 331    제주특별자치도  65~69세         30856       981     22717     4229     2929
# 332    제주특별자치도  70~74세         24555       358     17562     5277     1358
# 333    제주특별자치도  75~79세         19682       267     12311     6414      690
# 334    제주특별자치도  80~84세         14662       135      7256     7023      248
# 335    제주특별자치도   85세이상         12456       178      3193     8956      129
#
# ...

# %% [markdown]
# # [2019년 연령별 차량](https://stat.molit.go.kr/portal/cate/statFileView.do?hRsId=58&hFormId=5409&hSelectId=5409&sStyleNum=&sStart=&sEnd=&hPoint=&hAppr=&oFileName=&rFileName=&midpath=)

# %%
# https://stat.molit.go.kr/portal/cate/statFileView.do?hRsId=58&hFormId=5409&hSelectId=5409&sStyleNum=&sStart=&sEnd=&hPoint=&hAppr=&oFileName=&rFileName=&midpath=
df3 = pd.read_csv(path + '2019년_연령별_차량.csv', encoding='UTF-8')

# %%
df3
# Out:
#      성별     연령/시도          총계         서울         부산         대구         인천  \
# 0    남성    10대 이하       8,124      1,174        468        309        424
# 1   NaN       20대     371,936     38,840     19,884     18,729     24,623
# 2   NaN       30대   2,309,544    330,112    128,171    111,198    137,426
# 3   NaN       40대   3,924,378    518,595    208,583    196,436    215,660
# 4   NaN       50대   4,340,956    528,690    228,753    229,646    230,381
# 5   NaN       60대   3,020,028    401,828    185,675    157,377    147,546
# 6   NaN       70대     955,614    144,131     58,880     49,654     38,547
# 7   NaN       80대     150,651     23,860      8,228      7,684      5,177
# 8   NaN    90대 이상      13,628      2,829        813        582        491
# 9   NaN         계  15,094,859  1,990,059    839,455    771,615    800,275
# 10   여성    10대 이하       4,309        620        273        152        267
# 11  NaN       20대     177,616     18,213      8,715      8,500     10,849
# ...

# %% [markdown]
# ### 성별 NaN 값 채우기

# %%
df3['성별'][:10] = '남성'
df3['성별'][10:20] = '여성'

# %%
df3
# Out:
#     성별     연령/시도          총계         서울         부산         대구         인천  \
# 0   남성    10대 이하       8,124      1,174        468        309        424
# 1   남성       20대     371,936     38,840     19,884     18,729     24,623
# 2   남성       30대   2,309,544    330,112    128,171    111,198    137,426
# 3   남성       40대   3,924,378    518,595    208,583    196,436    215,660
# 4   남성       50대   4,340,956    528,690    228,753    229,646    230,381
# 5   남성       60대   3,020,028    401,828    185,675    157,377    147,546
# 6   남성       70대     955,614    144,131     58,880     49,654     38,547
# 7   남성       80대     150,651     23,860      8,228      7,684      5,177
# 8   남성    90대 이상      13,628      2,829        813        582        491
# 9   남성         계  15,094,859  1,990,059    839,455    771,615    800,275
# 10  여성    10대 이하       4,309        620        273        152        267
# 11  여성       20대     177,616     18,213      8,715      8,500     10,849
# ...

# %% [markdown]
# ### transpose 해서 열 설정하기

# %%
df3 = df3.T
df3.head()
# Out:
#            0        1          2          3          4          5        6   \
# 성별         남성       남성         남성         남성         남성         남성       남성
# 연령/시도  10대 이하      20대        30대        40대        50대        60대      70대
# 총계      8,124  371,936  2,309,544  3,924,378  4,340,956  3,020,028  955,614
# 서울      1,174   38,840    330,112    518,595    528,690    401,828  144,131
# 부산        468   19,884    128,171    208,583    228,753    185,675   58,880
#
#             7       8           9       10       11       12         13  \
# 성별          남성      남성          남성      여성       여성       여성         여성
# 연령/시도      80대  90대 이상           계  10대 이하      20대      30대        40대
# 총계     150,651  13,628  15,094,859   4,309  177,616  871,652  1,408,669
# 서울      23,860   2,829   1,990,059     620   18,213  118,733    186,243
# 부산       8,228     813     839,455     273    8,715   46,155     75,870
#
#               14       15       16      17      18         19         20  \
# ...

# %%
df3.iloc[1].values[:]
# Out:
# array(['10대 이하', '20대', '30대', '40대', '50대', '60대', '70대', '80대',
#        '90대 이상', '계', '10대 이하', '20대', '30대', '40대', '50대', '60대', '70대',
#        '80대', '90대 이상', '계', '법인 및 사업자', nan], dtype=object)

# %%
columns = ['10대 이하(남)', '20대(남)', '30대(남)', '40대(남)', '50대(남)', '60대(남)', '70대(남)', '80대(남)', '90대 이상(남)', '계(남)',
           '10대 이하(여)', '20대(여)', '30대(여)', '40대(여)', '50대(여)', '60대(여)', '70대(여)', '80대(여)', '90대 이상(여)', '계',
           '법인 및 사업자', '합계']

# %%
df3.set_axis(df3.iloc[1], axis=1, inplace=True)
# Out:
# <ipython-input-157-1f749da96cef>:1: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   df3.set_axis(df3.iloc[1], axis=1, inplace=True)

# %%
df3.columns = columns

# %%
df3.head()
# Out:
#       10대 이하(남)   20대(남)     30대(남)     40대(남)     50대(남)     60대(남)   70대(남)  \
# 성별           남성       남성         남성         남성         남성         남성       남성
# 연령/시도    10대 이하      20대        30대        40대        50대        60대      70대
# 총계        8,124  371,936  2,309,544  3,924,378  4,340,956  3,020,028  955,614
# 서울        1,174   38,840    330,112    518,595    528,690    401,828  144,131
# 부산          468   19,884    128,171    208,583    228,753    185,675   58,880
#
#         80대(남) 90대 이상(남)        계(남) 10대 이하(여)   20대(여)   30대(여)     40대(여)  \
# 성별          남성        남성          남성        여성       여성       여성         여성
# 연령/시도      80대    90대 이상           계    10대 이하      20대      30대        40대
# 총계     150,651    13,628  15,094,859     4,309  177,616  871,652  1,408,669
# 서울      23,860     2,829   1,990,059       620   18,213  118,733    186,243
# 부산       8,228       813     839,455       273    8,715   46,155     75,870
#
# ...

# %%
df3.index[0:2]
# Out:
# Index(['성별', '연령/시도'], dtype='object')

# %%
df3.drop(df3.index[0:2], inplace=True)

# %%
df3
# Out:
#    10대 이하(남)   20대(남)     30대(남)     40대(남)     50대(남)     60대(남)   70대(남)  \
# 총계     8,124  371,936  2,309,544  3,924,378  4,340,956  3,020,028  955,614
# 서울     1,174   38,840    330,112    518,595    528,690    401,828  144,131
# 부산       468   19,884    128,171    208,583    228,753    185,675   58,880
# 대구       309   18,729    111,198    196,436    229,646    157,377   49,654
# 인천       424   24,623    137,426    215,660    230,381    147,546   38,547
# 광주       195   12,695     68,844    119,316    125,384     74,883   24,284
# 대전       401   12,341     70,743    116,826    129,037     86,108   25,071
# 울산       237    9,340     59,463    100,496    130,749     81,982   19,651
# 세종        76    2,124     22,787     37,467     26,450     15,840    4,225
# 경기     2,277   99,616    643,424  1,074,548  1,084,480    661,747  187,379
# 강원       198   14,305     66,115    122,651    155,167    124,298   41,490
# ...

# %% [markdown]
# ### 저장 및 확인

# %%
df3.to_csv(path + '2019년_연령별_차량', index=True)

# %%
df3 = pd.read_csv(path + '2019년_연령별_차량')
df3
# Out:
#    Unnamed: 0 10대 이하(남)   20대(남)     30대(남)     40대(남)     50대(남)     60대(남)  \
# 0          총계     8,124  371,936  2,309,544  3,924,378  4,340,956  3,020,028
# 1          서울     1,174   38,840    330,112    518,595    528,690    401,828
# 2          부산       468   19,884    128,171    208,583    228,753    185,675
# 3          대구       309   18,729    111,198    196,436    229,646    157,377
# 4          인천       424   24,623    137,426    215,660    230,381    147,546
# 5          광주       195   12,695     68,844    119,316    125,384     74,883
# 6          대전       401   12,341     70,743    116,826    129,037     86,108
# 7          울산       237    9,340     59,463    100,496    130,749     81,982
# 8          세종        76    2,124     22,787     37,467     26,450     15,840
# 9          경기     2,277   99,616    643,424  1,074,548  1,084,480    661,747
# 10         강원       198   14,305     66,115    122,651    155,167    124,298
# ...

# %%
df3.rename(columns={"Unnamed: 0": '시도'}, inplace=True)
df3
# Out:
#     시도 10대 이하(남)   20대(남)     30대(남)     40대(남)     50대(남)     60대(남)  \
# 0   총계     8,124  371,936  2,309,544  3,924,378  4,340,956  3,020,028
# 1   서울     1,174   38,840    330,112    518,595    528,690    401,828
# 2   부산       468   19,884    128,171    208,583    228,753    185,675
# 3   대구       309   18,729    111,198    196,436    229,646    157,377
# 4   인천       424   24,623    137,426    215,660    230,381    147,546
# 5   광주       195   12,695     68,844    119,316    125,384     74,883
# 6   대전       401   12,341     70,743    116,826    129,037     86,108
# 7   울산       237    9,340     59,463    100,496    130,749     81,982
# 8   세종        76    2,124     22,787     37,467     26,450     15,840
# 9   경기     2,277   99,616    643,424  1,074,548  1,084,480    661,747
# 10  강원       198   14,305     66,115    122,651    155,167    124,298
# 11  충북       320   16,438     80,315    134,450    167,800    120,875
# ...

# %%
df3.to_csv(path + '2019년_연령별_차량', index=False)

# %%
pd.read_csv(path + '2019년_연령별_차량')
# Out:
#     시도 10대 이하(남)   20대(남)     30대(남)     40대(남)     50대(남)     60대(남)  \
# 0   총계     8,124  371,936  2,309,544  3,924,378  4,340,956  3,020,028
# 1   서울     1,174   38,840    330,112    518,595    528,690    401,828
# 2   부산       468   19,884    128,171    208,583    228,753    185,675
# 3   대구       309   18,729    111,198    196,436    229,646    157,377
# 4   인천       424   24,623    137,426    215,660    230,381    147,546
# 5   광주       195   12,695     68,844    119,316    125,384     74,883
# 6   대전       401   12,341     70,743    116,826    129,037     86,108
# 7   울산       237    9,340     59,463    100,496    130,749     81,982
# 8   세종        76    2,124     22,787     37,467     26,450     15,840
# 9   경기     2,277   99,616    643,424  1,074,548  1,084,480    661,747
# 10  강원       198   14,305     66,115    122,651    155,167    124,298
# 11  충북       320   16,438     80,315    134,450    167,800    120,875
# ...
